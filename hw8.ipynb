# %% [markdown]
# <a href="https://colab.research.google.com/github/hxujs346/hxujs346/blob/main/hw8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/hxujs346/main/refs/heads/main/balance_sheet.csv?token=GHSAT0AAAAAAC43RQLPMLGR3GMAKQJ7SQXCZ4AF57A"

# %%
df1 = pd.read_csv(url, index_col=0, encoding='unicode_escape')

# %%
df1
# Out:
#           YYYY/MM  Quarter consolidation  Month Currency  \
# CO_ID
# 1101 TCC  2023/12        4             Y     12      NTD
# 1102 ACC  2023/12        4             Y     12      NTD
#
#           Total cash and cash equivalents  \
# CO_ID
# 1101 TCC                       66366622.0
# 1102 ACC                       33229516.0
#
#           Total current financial assets at fair value through profit or loss  \
# CO_ID
# 1101 TCC                                           727762.0
# 1102 ACC                                         39719980.0
#
#           Financial assets at fair value through other comprehensive income - Current  \
# CO_ID
# 1101 TCC                                          6972790.0
# 1102 ACC                                          4307126.0
#
#           Financial assets measured at amortized cost - Current  \
# CO_ID
# 1101 TCC                                         34236957.0
# 1102 ACC                                         21684983.0
#
#           Current financial assets for hedging  ...  \
# CO_ID                                           ...
# 1101 TCC                                   0.0  ...
# 1102 ACC                                   0.0  ...
#
#           Other equity - unearned compensation  Other equity, others  \
# CO_ID
# 1101 TCC                                   0.0                   0.0
# 1102 ACC                                   0.0                   0.0
#
#           Total other equity interest  Treasury shares  \
# CO_ID
# 1101 TCC                    9457953.0      (732459.00)
# 1102 ACC                    7219740.0            0.00
#
#           Total equity attributable to owners of parent  \
# CO_ID
# 1101 TCC                                    230933254.0
# 1102 ACC                                    169169896.0
#
#           Interests in the former associate or jointly controlled entity  \
# CO_ID
# 1101 TCC                                                0.0
# 1102 ACC                                                0.0
#
#           Non-controlling interest in pre-acquisition share capital  \
# CO_ID
# 1101 TCC                                                0.0
# 1102 ACC                                                0.0
#
#           Non-controlling interests  Total equity  Total liabilities & equity
# CO_ID
# 1101 TCC                 22967787.0   253901041.0                 469438522.0
# 1102 ACC                 22693671.0   191863567.0                 336726851.0
#
# [2 rows x 111 columns]

# %%
url = "https://raw.githubusercontent.com/hxujs346/main/refs/heads/main/income_statement.csv?token=GHSAT0AAAAAAC5C2TMVBFGXKIVXIJ6442EAZ4AGV7A"

# %%
df2 = pd.read_csv(url, index_col=0, encoding='unicode_escape')

# %%
df2
# Out:
#           YYYY/MM  Quarter consolidation  Month Currency  \
# CO_ID
# 1101 TCC  2023/12        4             Y     12      NTD
# 1102 ACC  2023/12        4             Y     12      NTD
#
#           Gross operating revenue  Total rental revenue  \
# CO_ID
# 1101 TCC              109314335.0                   0.0
# 1102 ACC               78727593.0              992954.0
#
#           Operating revenue - Disposal of lands  Interest revenue  \
# CO_ID
# 1101 TCC                                    0.0               0.0
# 1102 ACC                                    0.0               0.0
#
#           Operating revenue - disposal of investments  ...  \
# CO_ID                                                  ...
# 1101 TCC                                          0.0  ...
# 1102 ACC                                    2461434.0  ...
#
#           Preferred stock dividends  Diluted net income  \
# CO_ID
# 1101 TCC                   350000.0           7951328.0
# 1102 ACC                        0.0          10882826.0
#
#           Total diluted earnings per share  \
# CO_ID
# 1101 TCC                              1.04
# 1102 ACC                              3.28
#
#           Average diluted common shares (Thousand)  \
# CO_ID
# 1101 TCC                                 7659839.0
# 1102 ACC                                 3320343.0
#
#           Earnings before interest and tax  \
# CO_ID
# 1101 TCC                        17899515.0
# 1102 ACC                        15708818.0
#
#           Earnings before interest, tax, depreciation and amortization  \
# CO_ID
# 1101 TCC                                         27184237.0
# 1102 ACC                                         20464516.0
#
#           Recurring net income  Treasury shares-buys back  \
# CO_ID
# 1101 TCC            10600473.0                    20000.0
# 1102 ACC             8010305.0                        0.0
#
#           Treasury shares-subsidiary holding  Total treasury shares
# CO_ID
# 1101 TCC                                 0.0                20000.0
# 1102 ACC                                 0.0                    0.0
#
# [2 rows x 133 columns]

# %%
df1.columns
# Out:
# Index(['YYYY/MM', 'Quarter', 'consolidation', 'Month', 'Currency',
#        'Total cash and cash equivalents',
#        'Total current financial assets at fair value through profit or loss',
#        'Financial assets at fair value through other comprehensive income - Current',
#        'Financial assets measured at amortized cost - Current',
#        'Current financial assets for hedging',
#        ...
#        'Other equity - unearned compensation', 'Other equity, others',
#        'Total other equity interest', 'Treasury shares',
#        'Total equity attributable to owners of parent',
#        'Interests in the former associate or jointly controlled entity',
#        'Non-controlling interest in pre-acquisition share capital',
#        'Non-controlling interests', 'Total equity',
#        'Total liabilities & equity'],
#       dtype='object', length=111)

# %%
df1.index
# Out:
# Index(['1101 TCC', '1102 ACC'], dtype='object', name='CO_ID')

# %%
A_1101 = (df1.loc['1101 TCC','Total current assets'] - df1.loc['1101 TCC','Total current liabilities'])/df1.loc['1101 TCC','Total assets']

# %%
A_1101
# Out:
# 0.17154975620002486

# %%
X1 ='Total current assets'
X2 ='Total current liabilities'
X3 ='Total assets'
X4 ='Total retained earnings'
X5 ='Earnings before interest and tax'
X6 ='Total equity'
X7 ='Total liabilities'
X8 ='Total operating revenue'
TCC ='1101 TCC'
ACC ='1102 ACC'

# %%
A_TCC = (df1.loc[TCC,X1] - df1.loc[TCC,X2])/df1.loc[TCC, X3]

# %%
B_TCC = df1.loc[TCC,X4]/df1.loc[TCC, X3]

# %%
C_TCC = df2.loc[TCC,X5]/df1.loc[TCC, X3]

# %%
D_TCC = df1.loc[TCC,X6]/df1.loc[TCC, X7] #調整分子項定義，採用股東權益帳面價值

# %%
E_TCC = df2.loc[TCC,X8]/df1.loc[TCC, X3]

# %%
Z_score_TCC = 1.2*A_TCC + 1.4*B_TCC + 3.3*C_TCC + 0.6*D_TCC +1.0*E_TCC

# %%
Z_score_TCC, A_TCC, B_TCC, C_TCC, D_TCC, E_TCC
# Out:
# (1.4818236254578403,
#  0.17154975620002486,
#  0.15034296865820485,
#  0.03812962541663762,
#  1.177990203012533,
#  0.23286187621389964)

# %%
A_ACC = (df1.loc[ACC,X1] - df1.loc[ACC,X2])/df1.loc[ACC, X3]

# %%
B_ACC = df1.loc[ACC,X4]/df1.loc[ACC, X3]

# %%
C_ACC = df2.loc[ACC,X5]/df1.loc[ACC, X3]

# %%
D_ACC = df1.loc[ACC,X6]/df1.loc[ACC, X7]

# %%
E_ACC = df2.loc[ACC,X8]/df1.loc[ACC, X3]

# %%
Z_score_ACC = 1.2*A_ACC + 1.4*B_ACC + 3.3*C_ACC + 0.6*D_ACC +1.0*E_ACC

# %%
Z_score_ACC, A_ACC, B_ACC, C_ACC, D_ACC, E_ACC
# Out:
# (1.8246460738677195,
#  0.11716660516627467,
#  0.3501663370468784,
#  0.046651515771161355,
#  1.3244457926274817,
#  0.2451957981812386)
